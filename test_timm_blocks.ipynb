# %%
import timm
import torch
from timm.models._efficientnet_blocks import UniversalInvertedResidual
from timm.layers.conv_bn_act import ConvNormAct
from rich import print
from torchinfo import summary

# %%
timm.list_models("mobilenetv3*")
# Out:
# ['mobilenetv3_large_075',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_150d',
#  'mobilenetv3_rw',
#  'mobilenetv3_small_050',
#  'mobilenetv3_small_075',
#  'mobilenetv3_small_100']

# %%
model = timm.create_model("mobilenetv4_conv_medium", features_only=True, in_chans=1)
model.blocks.pop(-1)
model._stage_out_idx = (4, 3, 2, 1, 0)
i = torch.randn(1, 1, 480, 768)
o = model(i)
for j in o:
    print(j.shape)
print(model.feature_info.channels())
summary(model,
        input_size=(1, 1, 480, 768),
        col_names=("input_size", "output_size", "num_params", "params_percent", "mult_adds"),
        depth=3)
# Out:
# torch.Size([1, 32, 240, 384])
# torch.Size([1, 48, 120, 192])
# torch.Size([1, 80, 60, 96])
# torch.Size([1, 160, 30, 48])
# torch.Size([1, 256, 15, 24])
# [32, 48, 80, 160, 960]
# ===============================================================================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #                   Param %                   Mult-Adds
# ===============================================================================================================================================================================
# MobileNetV3Features                                [1, 1, 480, 768]          [1, 32, 240, 384]         --                             --                   --
# ├─Conv2d: 1-1                                      [1, 1, 480, 768]          [1, 32, 240, 384]         288                         0.00%                   26,542,080
# ├─BatchNorm2d: 1-2                                 [1, 32, 240, 384]         [1, 32, 240, 384]         64                          0.00%                   64
# ├─ReLU: 1-3                                        [1, 32, 240, 384]         [1, 32, 240, 384]         --                             --                   --
# ├─Sequential: 1-4                                  --                        --                        --                             --                   --
# │    └─Sequential: 2-1                             [1, 32, 240, 384]         [1, 48, 120, 192]         --                             --                   --
# │    │    └─EdgeResidual: 3-1                      [1, 32, 240, 384]         [1, 48, 120, 192]         43,360                      0.62%                   990,904,320
# │    └─Sequential: 2-2                             [1, 48, 120, 192]         [1, 80, 60, 96]           --                             --                   --
# │    │    └─UniversalInvertedResidual: 3-2         [1, 48, 120, 192]         [1, 80, 60, 96]           30,832                      0.44%                   338,411,520
# │    │    └─UniversalInvertedResidual: 3-3         [1, 80, 60, 96]           [1, 80, 60, 96]           28,720                      0.41%                   159,897,600
# │    └─Sequential: 2-3                             [1, 80, 60, 96]           [1, 160, 30, 48]          --                             --                   --
# │    │    └─UniversalInvertedResidual: 3-4         [1, 80, 60, 96]           [1, 160, 30, 48]          130,320                     1.87%                   353,203,200
# │    │    └─UniversalInvertedResidual: 3-5         [1, 160, 30, 48]          [1, 160, 30, 48]          215,200                     3.09%                   305,280,000
# │    │    └─UniversalInvertedResidual: 3-6         [1, 160, 30, 48]          [1, 160, 30, 48]          215,200                     3.09%                   305,280,000
# │    │    └─UniversalInvertedResidual: 3-7         [1, 160, 30, 48]          [1, 160, 30, 48]          225,440                     3.24%                   320,025,600
# │    │    └─UniversalInvertedResidual: 3-8         [1, 160, 30, 48]          [1, 160, 30, 48]          215,200                     3.09%                   305,280,000
# │    │    └─UniversalInvertedResidual: 3-9         [1, 160, 30, 48]          [1, 160, 30, 48]          208,160                     2.99%                   296,985,600
# │    │    └─UniversalInvertedResidual: 3-10        [1, 160, 30, 48]          [1, 160, 30, 48]          103,360                     1.49%                   147,456,000
# │    │    └─UniversalInvertedResidual: 3-11        [1, 160, 30, 48]          [1, 160, 30, 48]          208,160                     2.99%                   296,985,600
# │    └─Sequential: 2-4                             [1, 160, 30, 48]          [1, 256, 15, 24]          --                             --                   --
# │    │    └─UniversalInvertedResidual: 3-12        [1, 160, 30, 48]          [1, 256, 15, 24]          432,032                     6.21%                   324,057,600
# │    │    └─UniversalInvertedResidual: 3-13        [1, 256, 15, 24]          [1, 256, 15, 24]          561,408                     8.07%                   200,263,680
# │    │    └─UniversalInvertedResidual: 3-14        [1, 256, 15, 24]          [1, 256, 15, 24]          557,312                     8.01%                   198,789,120
# │    │    └─UniversalInvertedResidual: 3-15        [1, 256, 15, 24]          [1, 256, 15, 24]          557,312                     8.01%                   198,789,120
# │    │    └─UniversalInvertedResidual: 3-16        [1, 256, 15, 24]          [1, 256, 15, 24]          526,848                     7.58%                   188,743,680
# │    │    └─UniversalInvertedResidual: 3-17        [1, 256, 15, 24]          [1, 256, 15, 24]          529,664                     7.62%                   189,573,120
# │    │    └─UniversalInvertedResidual: 3-18        [1, 256, 15, 24]          [1, 256, 15, 24]          280,320                     4.03%                   99,809,280
# │    │    └─UniversalInvertedResidual: 3-19        [1, 256, 15, 24]          [1, 256, 15, 24]          561,408                     8.07%                   200,263,680
# │    │    └─UniversalInvertedResidual: 3-20        [1, 256, 15, 24]          [1, 256, 15, 24]          526,848                     7.58%                   188,743,680
# │    │    └─UniversalInvertedResidual: 3-21        [1, 256, 15, 24]          [1, 256, 15, 24]          526,848                     7.58%                   188,743,680
# │    │    └─UniversalInvertedResidual: 3-22        [1, 256, 15, 24]          [1, 256, 15, 24]          270,592                     3.89%                   96,675,840
# ===============================================================================================================================================================================
# Total params: 6,954,896
# Trainable params: 6,954,896
# Non-trainable params: 0
# Total mult-adds (G): 5.92
# ===============================================================================================================================================================================
# Input size (MB): 1.47
# Forward/backward pass size (MB): 361.82
# Params size (MB): 27.57
# Estimated Total Size (MB): 390.86
# ===============================================================================================================================================================================

# %%
print(model)
# Out:
# MobileNetV3Features(
#   (conv_stem): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(32, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(128, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (bn): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(192, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(80, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(480, 480, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=480, bias=False)
#           (bn): BatchNormAct2d(
#             480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (2): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (3): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (4): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (5): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (6): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (7): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(960, 960, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=960, bias=False)
#           (bn): BatchNormAct2d(
#             960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (2): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (3): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (4): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (5): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (6): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (7): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (8): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (9): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (10): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#   )
# )

# %%
model = timm.create_model("resnet18", features_only=True)
# model._stage_out_idx = (4, 3, 2, 1, 0)
i = torch.randn(1, 3, 224, 224)
o = model(i)
for j in o:
    print(j.shape)
# Out:
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 64, 56, 56])
# torch.Size([1, 128, 28, 28])
# torch.Size([1, 256, 14, 14])
# torch.Size([1, 512, 7, 7])

# %%
model = timm.create_model("mobilenetv4_conv_medium", features_only=True,)
# print(model.feature_info.channels())
print(model)
# Out:
# MobileNetV3Features(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(32, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(128, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (bn): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(192, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(80, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (bn): BatchNormAct2d(
#             80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(480, 480, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=480, bias=False)
#           (bn): BatchNormAct2d(
#             480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (2): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (3): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (4): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (5): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (6): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (7): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(160, 160, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=160, bias=False)
#           (bn): BatchNormAct2d(
#             160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(960, 960, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=960, bias=False)
#           (bn): BatchNormAct2d(
#             960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (1): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (2): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (3): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (4): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (5): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (6): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (7): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): ConvNormAct(
#           (conv): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (8): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (9): UniversalInvertedResidual(
#         (dw_start): Identity()
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#       (10): UniversalInvertedResidual(
#         (dw_start): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (pw_exp): ConvNormAct(
#           (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (dw_mid): Identity()
#         (se): Identity()
#         (pw_proj): ConvNormAct(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (dw_end): Identity()
#         (layer_scale): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(256, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (aa): Identity()
#         (drop_path): Identity()
#       )
#     )
#   )
# )

# %%
a = torch.rand(1, 3, 224, 224)
conv = ConvNormAct(3, 3, 3, stride=2, dilation=2)
b = conv(a)
print(b.shape)
print(conv)
# Out:
# torch.Size([1, 3, 112, 112])
# ConvNormAct(
#   (conv): Conv2d(3, 3, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2), dilation=(2, 2), bias=False)
#   (bn): BatchNormAct2d(
#     3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): ReLU(inplace=True)
#   )
# )
